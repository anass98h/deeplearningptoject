# %% [markdown]
# # Augmentation
#
# ## RNN with augmentation
#
# ![image-5.png](attachment:image-5.png)
#
# ### RNN+mirror
#
#  Evaluation Metrics
# - Precision: 0.9452
# - Recall: 0.9857
# - F1-score: 0.9650
# - AUC: 0.9463
#
# ![image.png](attachment:image.png)
#
#
# ### RNN+rotate
#  Evaluation Metrics
# - Precision: 0.8800
# - Recall: 0.9429
# - F1-score: 0.9103
# - AUC: 0.8668
#
# ![image-2.png](attachment:image-2.png)
#
# ### RNN+stretch
#
#  Evaluation Metrics
# - Precision: 0.9211
# - Recall: 1.0000
# - F1-score: 0.9589
# - AUC: 0.9302
#
# ![image-3.png](attachment:image-3.png)
#
# ### RNN+cascade
#
# Evaluation Metrics
#
# - Precision: 0.9583
# - Recall: 0.9857
# - F1-score: 0.9718
# - AUC: 0.9580
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## CNN with augmentation

# %% [markdown]
# ![image-12.png](attachment:image-12.png)
#
# ## CNN+Aug_rotate
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)
#
# ### Evaluation Metrics
# - Precision: 0.8442
# - Recall: 0.9286
# - F1-score: 0.8844
# - AUC: 0.9555
#
#
# ## CNN+Aug_mirror
#
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
#
# Evaluation Metrics
# - Precision: 0.8750
# - Recall: 1.0000
# - F1-score: 0.9333
# - AUC: 0.9807
#
#
# ## CNN + AUG_scale
#
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# Evaluation Metrics
# - Precision: 0.8642
# - Recall: 1.0000
# - F1-score: 0.9272
# - AUC: 0.9495
#
# ## CNN+ cascade(Mirror + Rotate + Scale)
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
#
#
# Evaluation Metrics
# - Precision: 0.8193
# - Recall: 0.9714
# - F1-score: 0.8889
# - AUC: 0.921
